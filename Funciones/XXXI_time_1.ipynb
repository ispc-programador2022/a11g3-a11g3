# %%
# !pip install import_ipynb
# !pip install ipynb
import import_ipynb
import ipynb
import time
from google.colab import drive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
from IPython.display import clear_output 
import sys   
# %run XIV_genrnd.ipynb 
# %run XV_genrnd_1.ipynb        
# %run XVI_genrnd_2.ipynb
# %run XVII_media.ipynb  
# %run XIX_median.ipynb
# %run XX_range.ipynb
# %run XXI_variation.ipynb
# %run XXII_min.ipynb
# %run XXIII_max.ipynb

clear_output()
drive.mount('/content/drive')
sys.path.append('/content/drive/MyDrive/Proyecto_Situacion_Final/a11g3-a11g3/Funciones/')
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
sys.path.append('/content/drive/MyDrive/Colab Notebooks/')

# %% [markdown]
# Punto 31

# %%
# Previamente importando las funciones a utilizar
# También usaremos la libreria time, asi que la importamos

inicio = time.time()

lista_numeros = genrnd()
print("La media es: ", media(lista_numeros))
print("La mediana es: ",mediana(lista_numeros))
print("El rango es: ", rango(lista_numeros))
print("La varianza es: ", varianza(lista_numeros))
print("El mínimo es: ", minimo(lista_numeros))
print("El máximo es: ", maximo(lista_numeros))

fin = time.time()
print("----------------------------------")
print("El tiempo de ejecución es de: ", fin - inicio)
