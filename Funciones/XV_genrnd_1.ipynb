# %%
# !pip install import_ipynb
# !pip install ipynb
import import_ipynb
import ipynb
import random
from google.colab import drive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
from IPython.display import clear_output 
import sys
# %run I.welcome.ipynb
# %run II_ing2i.ipynb
# %run III_ing2s.ipynb 
# %run IV_sum.ipynb 
# %run V_rest.ipynb  
# %run VI_product.ipynb 
# %run VII_quotient.ipynb
# %run VIII_module.ipynb 
# %run IX_power.ipynb 
# %run X_rationalization.ipynb
# %run XI_P1.ipynb
# %run XII_P1_2.ipynb 
# %run XIII_P1_3.ipynb 
# %run XIV_genrnd.ipynb 
# %run XV_genrnd_1.ipynb        
# %run XVI_genrnd_2.ipynb
# %run XXVII_range_1.ipynb
# %run XVIII_genrnd_3.ipynb
# %run XIX_median.ipynb
# %run XX_range.ipynb
# %run XXI_variation.ipynb
# %run XXII_min.ipynb
# %run XXIII_max.ipynb
# %run XXIV_genrnd_4.ipynb
# %run XXV_average.ipynb -VER-
# %run XXVI_median_1.ipynb
# %run XVII_genrnd_2_3.ipynb
# %run XXVIII_variation_1.ipynb 
# %run XXIX_min_1.ipynb
# %run XXX_max_1.ipynb
# %run XXXI_time_1.ipynb
# %run XXXII_time_2.ipynb
# %run final_project.ipynb            

clear_output()
drive.mount('/content/drive')
sys.path.append('/content/drive/MyDrive/Proyecto_Situacion_Final/a11g3-a11g3/Funciones/')
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
sys.path.append('/content/drive/MyDrive/Colab Notebooks/')
# Out:
# Mounted at /content/drive

# %%
lista_1 =[]

def genrnd_suma(lista):
  for a in range(10):
    num = random.randint(1,50)
    num1 = random.randint(1,50)
    lista_2 = lista[num]+lista[num1]
    lista_1.append(lista_2)
  print(lista_1)

genrnd(1,100)
genrnd_suma(lista)
